# %% [markdown]
# # Using adzuna API + Scrapping in it

# %%
# ============================================================
# NOTEBOOK RUNNER
# Executes the three pipeline scripts in order with live output.
# ============================================================

import subprocess
import sys

scripts = [
    "2_adzuna_extract.py",
    "3_adzuna_scrape.py",
    "4_adzuna_export.py"
]

for script in scripts:
    print(f"\n{'='*50}", flush=True)
    print(f"Running {script}...", flush=True)
    print('='*50, flush=True)

    result = subprocess.run(
        [sys.executable, "-u", script],
        text=True
    )

    if result.returncode != 0:
        print(f"✗ ERROR in {script}", flush=True)
        break

    print(f"✓ {script} completed successfully", flush=True)

print("\n✓ All done!", flush=True)
# Out:
# ==================================================
# Running 2_adzuna_extract.py...
# ==================================================
# DEBUG: script started
# DEBUG: os imported
# DEBUG: time imported
# DEBUG: requests imported
# DEBUG: pandas imported
# DEBUG: dotenv imported
# DEBUG: importing adzuna_config...
# DEBUG: adzuna_config imported
# DEBUG: calling load_dotenv()
# DEBUG: load_dotenv finished
# ✓ 2_adzuna_extract.py completed successfully
#
# ==================================================
# Running 3_adzuna_scrape.py...
# ==================================================
# ✓ Loaded 6718 jobs from data/raw_jobs.csv
# ✓ Flagged 493 short/truncated jobs for re-scraping
# ✓ Keeping 6225 already well-scraped jobs
# ✓ geckodriver found at: /opt/homebrew/bin/geckodriver
#
# Scraping full descriptions from 6718 job pages...
#   💾 [6323/6718 — 94.1%] Checkpoint saved at job 4820
# Traceback (most recent call last):
#   File "/Users/ricardo.higginson@scalapay.com/Desktop/ironhack/project_api/3_adzuna_scrape.py", line 94, in <module>
#     time.sleep(2)  # wait 3 seconds for JS to fully render the page
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 20
#      17 print(f"Running {script}...", flush=True)
#      18 print('='*50, flush=True)
# ---> 20 result = subprocess.run(
#      21     [sys.executable, "-u", script],
#      22     text=True
#      23 )
#      25 if result.returncode != 0:
#      26     print(f"✗ ERROR in {script}", flush=True)
#
# File /opt/homebrew/Cellar/python@3.10/3.10.19/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py:505, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     503 with Popen(*popenargs, **kwargs) as process:
#     504     try:
# --> 505         stdout, stderr = process.communicate(input, timeout=timeout)
#     506     except TimeoutExpired as exc:
#     507         process.kill()
#
# File /opt/homebrew/Cellar/python@3.10/3.10.19/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py:1146, in Popen.communicate(self, input, timeout)
#    1144         stderr = self.stderr.read()
#    1145         self.stderr.close()
# -> 1146     self.wait()
#    1147 else:
#    1148     if timeout is not None:
#
# File /opt/homebrew/Cellar/python@3.10/3.10.19/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py:1209, in Popen.wait(self, timeout)
#    1207     endtime = _time() + timeout
#    1208 try:
# -> 1209     return self._wait(timeout=timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # The first keyboard interrupt waits briefly for the child to
#    1213     # exit under the common assumption that it also received the ^C
#    1214     # generated SIGINT and will exit rapidly.
#    1215     if timeout is not None:
#
# File /opt/homebrew/Cellar/python@3.10/3.10.19/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py:1959, in Popen._wait(self, timeout)
#    1957 if self.returncode is not None:
#    1958     break  # Another thread waited.
# -> 1959 (pid, sts) = self._try_wait(0)
#    1960 # Check the pid and loop as waitpid has been known to
#    1961 # return 0 even without WNOHANG in odd situations.
#    1962 # http://bugs.python.org/issue14396.
#    1963 if pid == self.pid:
#
# File /opt/homebrew/Cellar/python@3.10/3.10.19/Frameworks/Python.framework/Versions/3.10/lib/python3.10/subprocess.py:1917, in Popen._try_wait(self, wait_flags)
#    1915 """All callers to this function MUST hold self._waitpid_lock."""
#    1916 try:
# -> 1917     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1918 except ChildProcessError:
#    1919     # This happens if SIGCLD is set to be ignored or waiting
#    1920     # for child processes has otherwise been disabled for our
#    1921     # process.  This child is dead, we can't get the status.
#    1922     pid = self.pid
#
# KeyboardInterrupt:

# %%
#Not all jobs could have been re-scrapped. The urls that contains /detail/ cannot be scrapped due to bot detector
# Now we convert that links into /land/ links and scrap them, with output in a new file

# %%
script = "5_adzuna_rescrape.py"

print(f"\n{'='*50}", flush=True)
print(f"Running {script}...", flush=True)
print('='*50, flush=True)

result = subprocess.run(
    [sys.executable, "-u", script],
    text=True
)

if result.returncode != 0:
    print(f"✗ ERROR in {script}", flush=True)
else:
    print(f"✓ {script} completed successfully", flush=True)
# Out:
# ==================================================
# Running 5_adzuna_rescrape.py...
# ==================================================
# ✓ Loaded 65 rows from data/final_jobs.xlsx
# ✓ Firefox started
#
#
# ✓ Saved to data/final_jobs_fixed.xlsx  (original unchanged)
# ✓ 5_adzuna_rescrape.py completed successfully
